# %% [markdown]
# Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install zipfile36
# Out:
# Collecting zipfile36
#   Downloading zipfile36-0.1.3-py3-none-any.whl.metadata (736 bytes)
# Downloading zipfile36-0.1.3-py3-none-any.whl (20 kB)
# Installing collected packages: zipfile36
# Successfully installed zipfile36-0.1.3

# %%
import zipfile
import os

# Replace 'path/to/your/compressed/folder.zip' with the actual path
# to your compressed folder in Google Drive
zip_path = '/content/drive/MyDrive/dataset/CNN_assignment.zip'

# Create a ZipFile object
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # Get a list of all files in the compressed folder
    file_list = zip_ref.namelist()

    # Print the list of files
    print(file_list)

    # Extract all files to a specific directory (optional)
    #zip_ref.extractall('/content/drive/MyDrive/dataset/CNN_assignment')

    # Read a specific file from the compressed folder
    # Replace 'file_to_read.txt' with the actual file name
    # with zip_ref.open('file_to_read.txt') as file:
    #     contents = file.read().decode('utf-8')  # Decode if necessary
    #     print(contents)
# Out:
# ['Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0010512.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0010889.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024468.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024470.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024511.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024646.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024654.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024707.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024763.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024771.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024800.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024913.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024948.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0025368.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0025427.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0025605.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024331.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024332.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024345.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024360.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024403.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024411.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024431.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024432.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024436.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024443.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024448.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024452.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024454.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024457.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024461.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024472.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0001114.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0001130.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0011410.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0011433.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0011478.jpg', 'Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibrom ...

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path("/content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Create a dataset
#
# Defining  parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='training',
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='validation',
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.

class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Rescaling

target_labels = 9

# Use Input layer as the first layer
model = Sequential([
    Input(shape=(img_height, img_width, 3)),  # Define the input shape here
    Rescaling(1./255),                        # Normalize pixel values
    Conv2D(16, (3, 3), padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(32, (3, 3), padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(64, (3, 3), padding='same', activation='relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(target_labels, activation='softmax')  # Use softmax for classification
]
)

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 30976)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,965,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 9)                   │           1,161 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,989,801 (15.22 MB)
#  Trainable params: 3,989,801 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train the model

# %%
# %%time
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1720s 2s/step - accuracy: 0.2710 - loss: 1.9643 - val_accuracy: 0.4521 - val_loss: 1.4674
# Epoch 2/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 47s 17ms/step - accuracy: 0.4798 - loss: 1.3959 - val_accuracy: 0.5256 - val_loss: 1.2420
# Epoch 3/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.5744 - loss: 1.1292 - val_accuracy: 0.5947 - val_loss: 1.1290
# Epoch 4/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6759 - loss: 0.9070 - val_accuracy: 0.6244 - val_loss: 1.0061
# Epoch 5/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.7287 - loss: 0.7577 - val_accuracy: 0.7179 - val_loss: 0.8396
# Epoch 6/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7833 - loss: 0.5980 - val_accuracy: 0.7446 - val_loss: 0.8392
# Epoch 7/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8323 - loss: 0.4804 - val_accuracy: 0.7647 - val_loss: 0.7372
# Epoch 8/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8824 - loss: 0.3391 - val_accuracy: 0.7535 - val_loss: 0.7350
# Epoch 9/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9018 - loss: 0.2911 - val_accuracy: 0.7840 - val_loss: 0.7296
# Epoch 10/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9104 - loss: 0.2587 - val_accuracy: 0.7869 - val_loss: 0.7193
# Epoch 11/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9241 - loss: 0.2174 - val_accuracy: 0.8233 - val_loss: 0.7358
# Epoch 12/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9314 - loss: 0.1930 - val_accuracy: 0.8248 - val_loss: 0.7040
# Epoch 13/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9483 - loss: 0.1338 - val_accuracy: 0.8359 - val_loss: 0.7104
# Epoch 14/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9496 - loss: 0.1276 - val_accuracy: 0.8122 - val_loss: 0.6914
# Epoch 15/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9454 - loss: 0.1425 - val_accuracy: 0.8077 - val_loss: 0.8047
# Epoch 16/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9491 - loss: 0.1351 - val_accuracy: 0.7572 - val_loss: 0.9581
# Epoch 17/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9513 - loss: 0.1442 - val_accuracy: 0.8307 - val_loss: 0.6936
# Epoch 18/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9521 - loss: 0.1166 - val_accuracy: 0.8092 - val_loss: 0.8484
# Epoch 19/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9503 - loss: 0.1335 - val_accuracy: 0.7966 - val_loss: 0.8855
# Epoch 20/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9437 - loss: 0.1473 - val_accuracy: 0.8114 - val_loss: 0.7860
# CPU times: user 1min 34s, sys: 6.21 s, total: 1min 41s
# Wall time: 30min 33s

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# ***Observations:***
#
# 1. By leveraging augmented data, overfitting has been effectively addressed.
#
# 2. The training and validation accuracy of the aforementioned model fall within a similar range.
#
# 3. Both the training and validation data are showing poor performance, indicating that the model is now exhibiting underfitting.

# %% [markdown]
# #### Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
# After you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
# Your code goes here

augmentation_data = keras.Sequential([
                                      layers.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
                                      layers.RandomRotation(0.1),
                                      layers.RandomZoom(0.1),
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
## Your code goes here.

from glob import glob

## find the image path for all class labels (lesions)
images_path_list = [ i for i in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]

## Extract the class labels (lesions)
lesions_list = [ os.path.basename(os.path.dirname(j)) for j in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]
print(len(lesions_list))
# Out:
# 2239

# %%
# Extract image path and class label in a dictionary
image_dict = dict(zip(images_path_list, lesions_list))
print(list(image_dict.items())[:5])
# Out:
# [('/content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025780.jpg', 'actinic keratosis'), ('/content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025803.jpg', 'actinic keratosis'), ('/content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025825.jpg', 'actinic keratosis'), ('/content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025953.jpg', 'actinic keratosis'), ('/content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025957.jpg', 'actinic keratosis')]

# %%
# View the image path and class label in a df
lesions_df = pd.DataFrame(list(image_dict.items()), columns=['Image Path', 'Label'])
lesions_df.head()
# Out:
#                                           Image Path              Label
# 0  /content/drive/MyDrive/dataset/CNN_assignment/...  actinic keratosis
# 1  /content/drive/MyDrive/dataset/CNN_assignment/...  actinic keratosis
# 2  /content/drive/MyDrive/dataset/CNN_assignment/...  actinic keratosis
# 3  /content/drive/MyDrive/dataset/CNN_assignment/...  actinic keratosis
# 4  /content/drive/MyDrive/dataset/CNN_assignment/...  actinic keratosis

# %%
## Inspecting the distribution of classes in the data
lesions_df[['Label']].value_counts()
# Out:
# Label
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: count, dtype: int64

# %%
# Visualize the distribution of classes using a countplot

import seaborn as sns

plt.figure(figsize=(10, 8))
sns.countplot(y="Label", data=lesions_df)
plt.title('No. of images belonging to a Type v/s Types of Skin Lesion', fontsize=16)
plt.xlabel('No. of images in a particular skin lesion type', fontsize=14)
plt.ylabel('Skin Lesion Types', fontsize=14)
plt.show()

# %%
round(lesions_df[['Label']].value_counts(normalize=True)*100, 2)
# Out:
# Label
# pigmented benign keratosis    20.63
# melanoma                      19.56
# basal cell carcinoma          16.79
# nevus                         15.94
# squamous cell carcinoma        8.08
# vascular lesion                6.21
# actinic keratosis              5.09
# dermatofibroma                 4.24
# seborrheic keratosis           3.44
# Name: proportion, dtype: float64

# %% [markdown]
# #### Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# ***Observations:***
#
# 1. A clear class imbalance is evident within the training data.
#
# 2. The class **"seborrheic keratosis"** comprises the smallest proportion of samples, accounting for approximately **3.44%**.
#
# 3. **"Pigmented benign keratosis"** and **"melanoma"** significantly outweigh other classes, representing approximately **20.63%** and **19.56%** of the data, respectively.

# %% [markdown]
# #### Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from Augmentor) (11.1.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from Augmentor) (4.67.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from Augmentor) (1.26.4)
# Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset = str(data_dir_train) + '/'


import Augmentor

for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x784828D900D0>: 100%|██████████| 500/500 [00:25<00:00, 19.62 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7847A50F37D0>: 100%|██████████| 500/500 [00:19<00:00, 25.74 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7847A50DED50>: 100%|██████████| 500/500 [00:20<00:00, 24.46 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7847FFF51D90>: 100%|██████████| 500/500 [01:14<00:00,  6.70 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3072x2304 at 0x7847A27B2910>: 100%|██████████| 500/500 [01:18<00:00,  6.40 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x784817F22710>: 100%|██████████| 500/500 [00:19<00:00, 25.62 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7847FFF48B90>: 100%|██████████| 500/500 [00:37<00:00, 13.40 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7847A2677C50>: 100%|██████████| 500/500 [00:19<00:00, 25.65 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7847A5524650>: 100%|██████████| 500/500 [00:19<00:00, 25.83 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
# Verifying the total count of images after the augmentation
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 9000

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
# extracting the augmented image paths in a list
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list_new[:5]
# Out:
# ['/content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031430.jpg_963de82c-c625-4dc2-8160-c5bd30ef54b4.jpg',
#  '/content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031430.jpg_d422c9e7-f7fc-4d30-881e-15194506d837.jpg',
#  '/content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027580.jpg_441503df-fc5a-4cef-b875-3cb65972b824.jpg',
#  '/content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026702.jpg_0b416aaa-140c-4c05-8123-b6f62a20f172.jpg',
#  '/content/drive/MyDrive/dataset/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026729.jpg_6908ac15-7b13-435e-9e12-f4d747c200f3.jpg']

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new[:5]
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis']

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Image Path','Label'])
# Use pd.concat instead of append
new_df = pd.concat([lesions_df, df2], ignore_index=True)
new_df.shape
# Out:
# (11239, 2)

# %%
# View the augmented image paths and labels in a new df
new_df.head()
# Out:
#                                           Image Path              Label
# 0  /content/drive/MyDrive/dataset/CNN_assignment/...  actinic keratosis
# 1  /content/drive/MyDrive/dataset/CNN_assignment/...  actinic keratosis
# 2  /content/drive/MyDrive/dataset/CNN_assignment/...  actinic keratosis
# 3  /content/drive/MyDrive/dataset/CNN_assignment/...  actinic keratosis
# 4  /content/drive/MyDrive/dataset/CNN_assignment/...  actinic keratosis

# %%
# Inspecting the classes after adding 500 samples per label
new_df['Label'].value_counts()
# Out:
# Label
# pigmented benign keratosis    1462
# melanoma                      1438
# basal cell carcinoma          1376
# nevus                         1357
# squamous cell carcinoma       1181
# vascular lesion               1139
# actinic keratosis             1114
# dermatofibroma                1095
# seborrheic keratosis          1077
# Name: count, dtype: int64

# %%
# Inspecting the classes (% age wise) after adding 500 samples per label
round(new_df['Label'].value_counts(normalize=True)*100, 2)
# Out:
# Label
# pigmented benign keratosis    13.01
# melanoma                      12.79
# basal cell carcinoma          12.24
# nevus                         12.07
# squamous cell carcinoma       10.51
# vascular lesion               10.13
# actinic keratosis              9.91
# dermatofibroma                 9.74
# seborrheic keratosis           9.58
# Name: proportion, dtype: float64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### Create a training dataset

# %%
# data_dir_train="path to directory with training data + data created using augmentor"

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 11239 files belonging to 9 classes.
# Using 8992 files for training.

# %% [markdown]
# #### Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 11239 files belonging to 9 classes.
# Using 2247 files for validation.

# %% [markdown]
# #### Create your model (make sure to include normalization)

# %%
## your code goes here

model = Sequential([
  augmentation_data,
  layers.Rescaling(1./255),
  layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation=tf.nn.relu),
  layers.Dense(target_labels)
])

# %% [markdown]
# #### Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### Train your model

# %%
# %%time
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 78s 231ms/step - accuracy: 0.3069 - loss: 3.4671 - val_accuracy: 0.1429 - val_loss: 33.0664
# Epoch 2/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 72s 223ms/step - accuracy: 0.4118 - loss: 1.5152 - val_accuracy: 0.4108 - val_loss: 1.6019
# Epoch 3/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 81s 220ms/step - accuracy: 0.4705 - loss: 1.3801 - val_accuracy: 0.4660 - val_loss: 1.3400
# Epoch 4/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 83s 223ms/step - accuracy: 0.5188 - loss: 1.2536 - val_accuracy: 0.5016 - val_loss: 1.2875
# Epoch 5/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 81s 221ms/step - accuracy: 0.5551 - loss: 1.1622 - val_accuracy: 0.5171 - val_loss: 1.2863
# Epoch 6/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 81s 219ms/step - accuracy: 0.5697 - loss: 1.0960 - val_accuracy: 0.4197 - val_loss: 1.7377
# Epoch 7/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 81s 217ms/step - accuracy: 0.5924 - loss: 1.0526 - val_accuracy: 0.5803 - val_loss: 1.0239
# Epoch 8/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 83s 222ms/step - accuracy: 0.5957 - loss: 1.0161 - val_accuracy: 0.4904 - val_loss: 1.5549
# Epoch 9/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 64s 229ms/step - accuracy: 0.6075 - loss: 0.9883 - val_accuracy: 0.5496 - val_loss: 1.2507
# Epoch 10/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 90s 256ms/step - accuracy: 0.6359 - loss: 0.9424 - val_accuracy: 0.5465 - val_loss: 1.1697
# Epoch 11/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 63s 224ms/step - accuracy: 0.6491 - loss: 0.9048 - val_accuracy: 0.5394 - val_loss: 1.2483
# Epoch 12/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 91s 255ms/step - accuracy: 0.6574 - loss: 0.8826 - val_accuracy: 0.5705 - val_loss: 1.1305
# Epoch 13/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 73s 221ms/step - accuracy: 0.6702 - loss: 0.8360 - val_accuracy: 0.3836 - val_loss: 2.2973
# Epoch 14/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 82s 223ms/step - accuracy: 0.6720 - loss: 0.8216 - val_accuracy: 0.3480 - val_loss: 3.3351
# Epoch 15/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 82s 223ms/step - accuracy: 0.6966 - loss: 0.7791 - val_accuracy: 0.4989 - val_loss: 1.6682
# Epoch 16/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 80s 217ms/step - accuracy: 0.6954 - loss: 0.7499 - val_accuracy: 0.6956 - val_loss: 0.8010
# Epoch 17/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 81s 215ms/step - accuracy: 0.7181 - loss: 0.7316 - val_accuracy: 0.5826 - val_loss: 1.2148
# Epoch 18/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 83s 219ms/step - accuracy: 0.7165 - loss: 0.7275 - val_accuracy: 0.4713 - val_loss: 1.8867
# Epoch 19/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 85s 231ms/step - accuracy: 0.7283 - loss: 0.6918 - val_accuracy: 0.4619 - val_loss: 1.9277
# Epoch 20/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 63s 226ms/step - accuracy: 0.7429 - loss: 0.6584 - val_accuracy: 0.7103 - val_loss: 0.7579
# Epoch 21/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 80s 218ms/step - accuracy: 0.7433 - loss: 0.6516 - val_accuracy: 0.7130 - val_loss: 0.7831
# Epoch 22/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 82s 219ms/step - accuracy: 0.7512 - loss: 0.6424 - val_accuracy: 0.6435 - val_loss: 1.0550
# Epoch 23/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 83s 225ms/step - accuracy: 0.7626 - loss: 0.6064 - val_accuracy: 0.4846 - val_loss: 2.3025
# Epoch 24/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 81s 220ms/step - accuracy: 0.7731 - loss: 0.5998 - val_accuracy: 0.5372 - val_loss: 1.8223
# Epoch 25/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 81s 218ms/step - accuracy: 0.7733 - loss: 0.5858 - val_accuracy: 0.6124 - val_loss: 1.3544
# Epoch 26/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 85s 229ms/step - accuracy: 0.7805 - loss: 0.5776 - val_accuracy: 0.7259 - val_loss: 0.7984
# Epoch 27/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 81s 225ms/step - accuracy: 0.7839 - loss: 0.5561 - val_accuracy: 0.7187 - val_loss: 0.8016
# Epoch 28/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 82s 227ms/step - accuracy: 0.8053 - loss: 0.5147 - val_accuracy: 0.7014 - val_loss: 0.8130
# Epoch 29/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 80s 221ms/step - accuracy: 0.8082 - loss: 0.5094 - val_accuracy: 0.7775 - val_loss: 0.6379
# Epoch 30/30
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 61s 218ms/step - accuracy: 0.7928 - loss: 0.5742 - val_accuracy: 0.5376 - val_loss: 2.2984
# CPU times: user 30min 21s, sys: 1min 35s, total: 31min 57s
# Wall time: 39min 56s

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ***Observations:***
#
# 1. Implementing batch normalization in the model yielded a slight uptick in both training and validation accuracy.
# 2. Formulating an alternative model without batch normalization aims to investigate prospective improvements in accuracy.

# %%
# create the model
model = Sequential([
  augmentation_data,
  layers.Rescaling(1./255),
  layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation=tf.nn.relu),
  layers.Dense(target_labels)
])

# %% [markdown]
# #### Compiling the model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# ModelCheckpoint callback is employed alongside the model.fit() training process to periodically save the model
# or its weights (in a checkpoint file)
checkpoint = ModelCheckpoint("model.keras", monitor="val_accuracy", save_best_only=True, mode="auto", verbose=1)

# Early stop the training when a monitored metric ceases to show improvement
earlystop = EarlyStopping(monitor="val_accuracy", patience=5, mode="auto", verbose=1)

# %% [markdown]
# #### Training the model

# %%
# %%time
# train the model
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[checkpoint, earlystop]
)
# Out:
# Epoch 1/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.1937 - loss: 2.2046
# Epoch 1: val_accuracy improved from -inf to 0.42635, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 64s 222ms/step - accuracy: 0.1941 - loss: 2.2034 - val_accuracy: 0.4263 - val_loss: 1.4914
# Epoch 2/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.4227 - loss: 1.4870
# Epoch 2: val_accuracy improved from 0.42635 to 0.49266, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 92s 257ms/step - accuracy: 0.4227 - loss: 1.4868 - val_accuracy: 0.4927 - val_loss: 1.3114
# Epoch 3/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.4876 - loss: 1.3259
# Epoch 3: val_accuracy improved from 0.49266 to 0.50512, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 70s 216ms/step - accuracy: 0.4876 - loss: 1.3259 - val_accuracy: 0.5051 - val_loss: 1.2675
# Epoch 4/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.5253 - loss: 1.2458
# Epoch 4: val_accuracy improved from 0.50512 to 0.56164, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 82s 216ms/step - accuracy: 0.5254 - loss: 1.2456 - val_accuracy: 0.5616 - val_loss: 1.1668
# Epoch 5/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.5556 - loss: 1.1585
# Epoch 5: val_accuracy improved from 0.56164 to 0.60303, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 85s 226ms/step - accuracy: 0.5557 - loss: 1.1585 - val_accuracy: 0.6030 - val_loss: 1.0617
# Epoch 6/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.5865 - loss: 1.1038
# Epoch 6: val_accuracy did not improve from 0.60303
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 79s 214ms/step - accuracy: 0.5865 - loss: 1.1038 - val_accuracy: 0.5937 - val_loss: 1.0625
# Epoch 7/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6049 - loss: 1.0590
# Epoch 7: val_accuracy improved from 0.60303 to 0.65332, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 82s 216ms/step - accuracy: 0.6049 - loss: 1.0589 - val_accuracy: 0.6533 - val_loss: 0.9409
# Epoch 8/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.6376 - loss: 0.9820
# Epoch 8: val_accuracy improved from 0.65332 to 0.65421, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 83s 218ms/step - accuracy: 0.6376 - loss: 0.9819 - val_accuracy: 0.6542 - val_loss: 0.9272
# Epoch 9/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.6465 - loss: 0.9333
# Epoch 9: val_accuracy did not improve from 0.65421
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 90s 247ms/step - accuracy: 0.6465 - loss: 0.9332 - val_accuracy: 0.6395 - val_loss: 0.9452
# Epoch 10/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.6679 - loss: 0.8874
# Epoch 10: val_accuracy improved from 0.65421 to 0.66266, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 85s 259ms/step - accuracy: 0.6679 - loss: 0.8873 - val_accuracy: 0.6627 - val_loss: 0.8915
# Epoch 11/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.6905 - loss: 0.8325
# Epoch 11: val_accuracy improved from 0.66266 to 0.67957, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 63s 223ms/step - accuracy: 0.6906 - loss: 0.8324 - val_accuracy: 0.6796 - val_loss: 0.8973
# Epoch 12/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7129 - loss: 0.7763
# Epoch 12: val_accuracy improved from 0.67957 to 0.71607, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 61s 218ms/step - accuracy: 0.7129 - loss: 0.7762 - val_accuracy: 0.7161 - val_loss: 0.7376
# Epoch 13/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7250 - loss: 0.7221
# Epoch 13: val_accuracy did not improve from 0.71607
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 61s 218ms/step - accuracy: 0.7250 - loss: 0.7220 - val_accuracy: 0.6822 - val_loss: 0.8160
# Epoch 14/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7289 - loss: 0.7314
# Epoch 14: val_accuracy improved from 0.71607 to 0.75745, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 81s 214ms/step - accuracy: 0.7290 - loss: 0.7313 - val_accuracy: 0.7575 - val_loss: 0.6954
# Epoch 15/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7578 - loss: 0.6565
# Epoch 15: val_accuracy did not improve from 0.75745
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 59s 211ms/step - accuracy: 0.7578 - loss: 0.6564 - val_accuracy: 0.7214 - val_loss: 0.7459
# Epoch 16/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.7594 - loss: 0.6422
# Epoch 16: val_accuracy improved from 0.75745 to 0.76146, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 82s 213ms/step - accuracy: 0.7595 - loss: 0.6422 - val_accuracy: 0.7615 - val_loss: 0.6141
# Epoch 17/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7697 - loss: 0.6196
# Epoch 17: val_accuracy improved from 0.76146 to 0.76769, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 82s 214ms/step - accuracy: 0.7698 - loss: 0.6196 - val_accuracy: 0.7677 - val_loss: 0.6465
# Epoch 18/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7780 - loss: 0.6101
# Epoch 18: val_accuracy improved from 0.76769 to 0.79039, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 61s 216ms/step - accuracy: 0.7781 - loss: 0.6100 - val_accuracy: 0.7904 - val_loss: 0.5714
# Epoch 19/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.7984 - loss: 0.5457
# Epoch 19: val_accuracy did not improve from 0.79039
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - accuracy: 0.7984 - loss: 0.5457 - val_accuracy: 0.7721 - val_loss: 0.6193
# Epoch 20/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8019 - loss: 0.5397
# Epoch 20: val_accuracy improved from 0.79039 to 0.80997, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 81s 214ms/step - accuracy: 0.8019 - loss: 0.5397 - val_accuracy: 0.8100 - val_loss: 0.5357
# Epoch 21/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8203 - loss: 0.4933
# Epoch 21: val_accuracy improved from 0.80997 to 0.82287, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 82s 213ms/step - accuracy: 0.8203 - loss: 0.4933 - val_accuracy: 0.8229 - val_loss: 0.4981
# Epoch 22/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8199 - loss: 0.4885
# Epoch 22: val_accuracy improved from 0.82287 to 0.82777, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 82s 214ms/step - accuracy: 0.8199 - loss: 0.4885 - val_accuracy: 0.8278 - val_loss: 0.4960
# Epoch 23/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8178 - loss: 0.4881
# Epoch 23: val_accuracy did not improve from 0.82777
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 62s 219ms/step - accuracy: 0.8178 - loss: 0.4882 - val_accuracy: 0.8180 - val_loss: 0.4987
# Epoch 24/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8432 - loss: 0.4343
# Epoch 24: val_accuracy improved from 0.82777 to 0.83044, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 92s 254ms/step - accuracy: 0.8432 - loss: 0.4343 - val_accuracy: 0.8304 - val_loss: 0.4680
# Epoch 25/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8257 - loss: 0.4642
# Epoch 25: val_accuracy improved from 0.83044 to 0.84424, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 71s 214ms/step - accuracy: 0.8258 - loss: 0.4641 - val_accuracy: 0.8442 - val_loss: 0.4554
# Epoch 26/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.8280 - loss: 0.4603
# Epoch 26: val_accuracy did not improve from 0.84424
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 95s 260ms/step - accuracy: 0.8280 - loss: 0.4603 - val_accuracy: 0.8238 - val_loss: 0.5105
# Epoch 27/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8453 - loss: 0.4243
# Epoch 27: val_accuracy did not improve from 0.84424
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 71s 219ms/step - accuracy: 0.8454 - loss: 0.4242 - val_accuracy: 0.8402 - val_loss: 0.4480
# Epoch 28/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8630 - loss: 0.3784
# Epoch 28: val_accuracy improved from 0.84424 to 0.84468, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 71s 254ms/step - accuracy: 0.8630 - loss: 0.3784 - val_accuracy: 0.8447 - val_loss: 0.4521
# Epoch 29/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8536 - loss: 0.3948
# Epoch 29: val_accuracy improved from 0.84468 to 0.85091, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 72s 218ms/step - accuracy: 0.8536 - loss: 0.3948 - val_accuracy: 0.8509 - val_loss: 0.4318
# Epoch 30/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8632 - loss: 0.3704
# Epoch 30: val_accuracy did not improve from 0.85091
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 62s 219ms/step - accuracy: 0.8632 - loss: 0.3704 - val_accuracy: 0.8220 - val_loss: 0.5426
# Epoch 31/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8642 - loss: 0.3602
# Epoch 31: val_accuracy did not improve from 0.85091
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 82s 220ms/step - accuracy: 0.8642 - loss: 0.3602 - val_accuracy: 0.8344 - val_loss: 0.4766
# Epoch 32/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8603 - loss: 0.3766
# Epoch 32: val_accuracy improved from 0.85091 to 0.86649, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 83s 224ms/step - accuracy: 0.8603 - loss: 0.3765 - val_accuracy: 0.8665 - val_loss: 0.3887
# Epoch 33/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8718 - loss: 0.3449
# Epoch 33: val_accuracy improved from 0.86649 to 0.86693, saving model to model.keras
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 79s 213ms/step - accuracy: 0.8718 - loss: 0.3449 - val_accuracy: 0.8669 - val_loss: 0.4134
# Epoch 34/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8742 - loss: 0.3331
# Epoch 34: val_accuracy did not improve from 0.86693
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 82s 214ms/step - accuracy: 0.8742 - loss: 0.3331 - val_accuracy: 0.8540 - val_loss: 0.4942
# Epoch 35/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8742 - loss: 0.3427
# Epoch 35: val_accuracy did not improve from 0.86693
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 82s 214ms/step - accuracy: 0.8741 - loss: 0.3427 - val_accuracy: 0.8416 - val_loss: 0.4435
# Epoch 36/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8661 - loss: 0.3723
# Epoch 36: val_accuracy did not improve from 0.86693
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 82s 214ms/step - accuracy: 0.8661 - loss: 0.3723 - val_accuracy: 0.8563 - val_loss: 0.3947
# Epoch 37/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.8740 - loss: 0.3169
# Epoch 37: val_accuracy did not improve from 0.86693
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 84s 222ms/step - accuracy: 0.8741 - loss: 0.3169 - val_accuracy: 0.8625 - val_loss: 0.3994
# Epoch 38/50
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.8848 - loss: 0.3105
# Epoch 38: val_accuracy did not improve from 0.86693
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 91s 256ms/step - accuracy: 0.8848 - loss: 0.3106 - val_accuracy: 0.8380 - val_loss: 0.4886
# Epoch 38: early stopping
# CPU times: user 36min 37s, sys: 1min 59s, total: 38min 36s
# Wall time: 49min 9s

# %% [markdown]
# #### Visualize the model results

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)            │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_2 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 30976)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │       3,965,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 9)                   │           1,161 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,969,405 (45.66 MB)
#  Trainable params: 3,989,801 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 7,979,604 (30.44 MB)

# %% [markdown]
#  Plot the training curves

# %%
epochs_range = range(earlystop.stopped_epoch+1)

plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)

#Plot Model Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')

#Plot Model Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# #### Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# ***Observations:***
#
# 1. The ultimate model showcases well-balanced performance, displaying no signs of underfitting or overfitting.
#
# 2. The implementation of class rebalancing has notably enhanced the model's performance across both training and validation datasets.
#
# 3. Following 50 epochs, the final model attains an accuracy of 89% on the training set and approximately 84% on the validation set.
#
# 4. The narrow divergence between training and validation accuracies underscores the robust generalization capability of the final CNN model.
#
# 5. The addition of batch normalization failed to enhance both training and validation accuracy.

# %% [markdown]
# ### Model Evaluation

# %%
# Evaluating our model on one of the instances in the test set

from tensorflow.keras.preprocessing.image import load_img

image_path_test = os.path.join(data_dir_test, class_names[1], '*')
test_image = glob(image_path_test)
test_image = load_img(test_image[-1], target_size=(180, 180, 3))
plt.imshow(test_image)
plt.grid(False)

img = np.expand_dims(test_image, axis=0)
predicted = model.predict(img)
predicted = np.argmax(predicted)
predicted_class = class_names[predicted]
print("Actual Class: " + class_names[1] +'\n'+ "Predicted Class: " + predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# Actual Class: basal cell carcinoma
# Predicted Class: basal cell carcinoma
